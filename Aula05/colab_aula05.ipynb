# %% [markdown]
# # **Carregando dados de embaixadinha**
# Dados disponíveis no:
# [Github da disciplina](https://github.com/paulopreto/REF0007_Nocoes_estatistica/tree/main/Aula03)

# %%
# Importando a biblioteca pandas
import pandas as pd

# %%
# Lendo os arquivos de dados com a biblioteca pandas 
df_embaixaforms = pd.read_excel('/content/embaixadinha_2021 (respostas).xlsx')
df_embaixamanual = pd.read_excel('/content/embaixadinha_2021_manual.xlsx')

# df_embaixaforms = pd.read_csv('/content/embaixadinha_2021 (respostas) - Respostas ao formulário 1.csv')
# df_embaixamanual = pd.read_csv('/content/embaixadinha_2021_manual.csv')

# %% [markdown]
# **Para remover colunas ou linhas usar o método drop | dropnan**

# %%
# Removendo a coluna de Endereço de e-mail, pois ela está sem informações
df_embaixaforms.drop(columns=['Endereço de e-mail'], inplace=True)
df_embaixamanual.drop(columns=['Endereço de e-mail'], inplace=True)

# %%
print(df_embaixamanual.shape)
df_embaixamanual.dropna(subset=['Qual seu número USP?'], inplace=True)
print(df_embaixamanual.shape)
# Out:
# (59, 13)
# (58, 13)

# %%
df_embaixaforms.drop(columns=['Carimbo de data/hora'], inplace=True)
df_embaixamanual.drop(columns=['Carimbo de data/hora'], inplace=True)

# %%
df_embaixamanual
# Out:
#     Qual seu número USP?  ... Quantas embaixadinhas você conseguiu fazer?
# 0             12529631.0  ...                                        38.0
# 1             12423283.0  ...                                        34.0
# 2             10716309.0  ...                                         8.0
# 4             11929570.0  ...                                         5.0
# 5             12606679.0  ...                                        12.0
# 6             12703890.0  ...                                        37.0
# 7             12529728.0  ...                                        15.0
# 8             11855300.0  ...                                         2.0
# 9              9922418.0  ...                                        23.0
# 10            12529687.0  ...                                         2.0
# 11            12530161.0  ...                                         3.0
# 12            12606662.0  ...                                         2.0
# ...

# %% [markdown]
# **Verificando se existem números USP duplicados/se alguém respondeu mais de uma vez na planilha manual**

# %%
df_embaixamanual.duplicated(subset=['Qual seu número USP?'])
# Out:
# 0     False
# 1     False
# 2     False
# 4     False
# 5     False
# 6     False
# 7     False
# 8     False
# 9     False
# 10    False
# 11    False
# 12    False
# 13    False
# 14    False
# 15    False
# 16    False
# 17    False
# 18    False
# 19    False
# 20    False
# 21    False
# 22    False
# 23    False
# 24    False
# 25    False
# 26    False
# 27    False
# 28    False
# 29    False
# 30    False
# 31    False
# 32    False
# 33    False
# 34    False
# 35    False
# 36    False
# 37    False
# 38    False
# 39    False
# 40    False
# 41    False
# 42    False
# 43    False
# 44    False
# 45    False
# 46    False
# 47    False
# 48    False
# 49    False
# 50    False
# 51    False
# 52    False
# 53    False
# 54    False
# 55    False
# 56    False
# 57    False
# 58    False
# dtype: bool

# %%
# Removendo quem tem número USP duplicado, mantendo o primeiro e apagando os próximos
df_embaixamanual.drop_duplicates(subset=['Qual seu número USP?'], inplace=True, keep='first')

# %%
# Contar quantos são do sexo masculino (M) e quantos são do sexo feminino (F)
df_embaixaforms['Sexo (M = masculino ou F = feminino)'].value_counts()
# Out:
# M    37
# F    25
# Name: Sexo (M = masculino ou F = feminino), dtype: int64

# %%
df_embaixaforms['Qual time de futebol do Brasil você torce?']
# Out:
# 0        Palmeiras
# 1      corinthians
# 2        São Paulo
# 3     São Paulo FC
# 4        Palmeiras
#           ...
# 57          nenhum
# 58        Flamengo
# 59       Palmeiras
# 60    Corinthians
# 61       Palmeiras
# Name: Qual time de futebol do Brasil você torce?, Length: 62, dtype: object

# %%
# Contar quantos times existem de torcida
df_embaixaforms['Qual time de futebol do Brasil você torce?'].value_counts()
# Out:
# Palmeiras                12
# São Paulo                10
# Corinthians               8
# NENHUM                    8
# Santos                    5
# Corinthians               4
# nenhum                    3
# Nenhum                    2
# Flamengo                  1
# vasco                     1
# Campinense Clube - PB     1
# Atlético Nacional         1
# São Paulo FC              1
# corinthians               1
# Atlético MG               1
# palmeiras                 1
# Fluminense                1
# Corithians                1
# Name: Qual time de futebol do Brasil você torce?, dtype: int64

# %%
# Ver tipo de dados no dataframe df.info() e type(df)
df_embaixaforms.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 62 entries, 0 to 61
# Data columns (total 12 columns):
#  #   Column                                                                 Non-Null Count  Dtype
# ---  ------                                                                 --------------  -----
#  0   Qual seu número USP?                                                   62 non-null     int64
#  1   Crie um pseudônimo para você?                                          62 non-null     object
#  2   Qual sua data de nascimento?                                           62 non-null     int64
#  3   Qual sua estatura em metros?                                           62 non-null     float64
#  4   Qual sua massa corporal em quilogramas?                                62 non-null     float64
#  5   Qual o número do seu calçado?                                          62 non-null     int64
# ...

# %% [markdown]
# # **Não considerar daqui pra frente**

# %%
with open('/content/nestarel.sbv', 'r', ) as f:
  lines = f.readlines()
print(lines)
# Out:
# ['00:02:08.313,00:02:11.313\n', 'Marina Zerbini Cardoso: Professor a aula de hoje será posta na edisciplina?\n', '\n', '00:02:27.824,00:02:30.824\n', 'Marina Zerbini Cardoso: Certo ! Obrigada 🙏🏻\n', '\n', '00:14:58.724,00:15:01.724\n', 'Gabriel de Carvalho Borges: física, biologia e história\n', '\n', '00:15:02.521,00:15:05.521\n', 'Gabriel de Carvalho Borges: segunda fase da fuvest\n', '\n', '00:15:13.424,00:15:16.424\n', 'Emanuel Thomazi Zuliani: Biologia História Fisica e química\n', '\n', '00:17:37.923,00:17:40.923\n', 'Isadora Silva Bezerra: quimica\n', '\n', '00:17:41.444,00:17:44.444\n', 'Murilo Barbosa de Carvalho: física \n', '\n', '00:17:41.514,00:17:44.514\n', 'Vitoria Marques da Silva: fisica\n', '\n', '00:17:41.604,00:17:44.604\n', 'Lara Nicolette Rodrigues de Lara: física kkkkk\n', '\n', '00:17:42.547,00:17:45.547\n', 'João Victor Gatto Torini: quimica\n', '\n', '00:17:42.779,00:17:45.779\n', 'Elber Henrique Luciani: quimica\n', '\n', '00:17:47.124,00:17:50.124\n', 'Isa
# ...

# %%
def searchingword(filename, word):
  counter = 0
  with open(filename) as f:
    for line in f:
      if word in line:
        print(word)
        counter += 1
  return counter

# %%
x = searchingword('/content/nestarel.sbv' , 'Silva')
# Out:
# Silva
# Silva
# Silva
# Silva
# Silva
# Silva
# Silva
# Silva
# Silva

# %%
word = 'Silva'
numlin = 0
for i in lines:
  numlin += 1
  if word in i:
    print(f'Linha {numlin} tem um {word}')
# Out:
# Linha 17 tem um Silva
# Linha 23 tem um Silva
# Linha 35 tem um Silva
# Linha 50 tem um Silva
# Linha 59 tem um Silva
# Linha 65 tem um Silva
# Linha 71 tem um Silva
# Linha 74 tem um Silva
# Linha 80 tem um Silva

# %%
df1['Nome'][1]
# Out:
# 'Douglas'
